# %%
import numpy as np
import pandas as pd
import os

# %%
display(dbutils.fs.ls('/FileStore/tables/'))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/FileStore/tables/retail.csv</td><td>retail.csv</td><td>45571666</td><td>1682002790000</td></tr></tbody></table></div>

# %% [markdown]
# ### 1. Ler e exibir um arquivo CSV usando pandas

# %%
df = spark.read.csv("/FileStore/tables/retail.csv", header=True, sep=',')
df = df.toPandas()
df.head()

# %%
df.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>invoice_no</th>
#       <th>stock_code</th>
#       <th>description</th>
#       <th>quantity</th>
#       <th>invoice_date</th>
#       <th>unit_price</th>
#       <th>customer_id</th>
#       <th>region</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>536365</td>
#       <td>85123A</td>
#       <td>WHITE HANGING HEART T-LIGHT HOLDER</td>
#       <td>6</td>
#       <td>12/1/10 8:26</td>
#       <td>2,55</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>536365</td>
#       <td>71053</td>
#       <td>WHITE METAL LANTERN</td>
#       <td>6</td>
#       <td>12/1/10 8:26</td>
#       <td>3,39</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>536365</td>
#       <td>84406B</td>
#       <td>CREAM CUPID HEARTS COAT HANGER</td>
#       <td>8</td>
#       <td>12/1/10 8:26</td>
#       <td>2,75</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>536365</td>
#       <td>84029G</td>
#       <td>KNITTED UNION FLAG HOT WATER BOTTLE</td>
#       <td>6</td>
#       <td>12/1/10 8:26</td>
#       <td>3,39</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>536365</td>
#       <td>84029E</td>
#       <td>RED WOOLLY HOTTIE WHITE HEART.</td>
#       <td>6</td>
#       <td>12/1/10 8:26</td>
#       <td>3,39</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# ### 2. Selecionar colunas específicas de um DataFrame usando pandas

# %%
df.filter(['description'])
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>WHITE HANGING HEART T-LIGHT HOLDER</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>WHITE METAL LANTERN</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>CREAM CUPID HEARTS COAT HANGER</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>KNITTED UNION FLAG HOT WATER BOTTLE</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>RED WOOLLY HOTTIE WHITE HEART.</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>541904</th>
#       <td>PACK OF 20 SPACEBOY NAPKINS</td>
#     </tr>
#     <tr>
#       <th>541905</th>
#       <td>CHILDREN'S APRON DOLLY GIRL</td>
#     </tr>
#     <tr>
#       <th>541906</th>
#       <td>CHILDRENS CUTLERY DOLLY GIRL</td>
#     </tr>
#     <tr>
#       <th>541907</th>
#       <td>CHILDRENS CUTLERY CIRCUS PARADE</td>
#     </tr>
#     <tr>
#       <th>541908</th>
#       <td>BAKING SET 9 PIECE RETROSPOT</td>
#     </tr>
#   </tbody>
# </table>
# <p>541909 rows × 1 columns</p>
# </div>

# %% [markdown]
# ### 3. Filtrar linhas com base em uma condição usando pandas

# %%
df.query('quantity>"8"')
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>invoice_no</th>
#       <th>stock_code</th>
#       <th>description</th>
#       <th>quantity</th>
#       <th>invoice_date</th>
#       <th>unit_price</th>
#       <th>customer_id</th>
#       <th>region</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>46</th>
#       <td>536371</td>
#       <td>22086</td>
#       <td>PAPER CHAIN KIT 50'S CHRISTMAS</td>
#       <td>80</td>
#       <td>12/1/10 9:00</td>
#       <td>2,55</td>
#       <td>13748</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>102</th>
#       <td>536378</td>
#       <td>85071B</td>
#       <td>RED CHARLIE+LOLA PERSONAL DOORSIGN</td>
#       <td>96</td>
#       <td>12/1/10 9:37</td>
#       <td>0,38</td>
#       <td>14688</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>224</th>
#       <td>536390</td>
#       <td>21080</td>
#       <td>SET/20 RED RETROSPOT PAPER NAPKINS</td>
#       <td>96</td>
#       <td>12/1/10 10:19</td>
#       <td>0,64</td>
#       <td>17511</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>225</th>
#       <td>536390</td>
#       <td>21094</td>
#       <td>SET/6 RED SPOTTY PAPER PLATES</td>
#       <td>96</td>
#       <td>12/1/10 10:19</td>
#       <td>0,64</td>
#       <td>17511</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>233</th>
#       <td>536390</td>
#       <td>22969</td>
#       <td>HOMEMADE JAM SCENTED CANDLES</td>
#       <td>96</td>
#       <td>12/1/10 10:19</td>
#       <td>1,25</td>
#       <td>17511</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>541597</th>
#       <td>581514</td>
#       <td>84032B</td>
#       <td>CHARLIE + LOLA RED HOT WATER BOTTLE</td>
#       <td>9</td>
#       <td>12/9/11 11:20</td>
#       <td>0,79</td>
#       <td>17754</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>541612</th>
#       <td>581514</td>
#       <td>21705</td>
#       <td>BAG 500g SWIRLY MARBLES</td>
#       <td>84</td>
#       <td>12/9/11 11:20</td>
#       <td>0,39</td>
#       <td>17754</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>541703</th>
#       <td>581567</td>
#       <td>21417</td>
#       <td>COCKLE SHELL DISH</td>
#       <td>84</td>
#       <td>12/9/11 11:56</td>
#       <td>0,79</td>
#       <td>16626</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>541746</th>
#       <td>581571</td>
#       <td>23167</td>
#       <td>SMALL CERAMIC TOP STORAGE JAR</td>
#       <td>96</td>
#       <td>12/9/11 12:00</td>
#       <td>0,69</td>
#       <td>15311</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>541800</th>
#       <td>581578</td>
#       <td>23298</td>
#       <td>SPOTTY BUNTING</td>
#       <td>9</td>
#       <td>12/9/11 12:16</td>
#       <td>4,95</td>
#       <td>12713</td>
#       <td>Germany</td>
#     </tr>
#   </tbody>
# </table>
# <p>4304 rows × 8 columns</p>
# </div>

# %% [markdown]
# ### 4. Agrupar dados com base em uma coluna usando pandas

# %%
df.groupby('stock_code').agg(soma=('quantity','sum')).reset_index()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>stock_code</th>
#       <th>soma</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>10002</td>
#       <td>4812115212415121218210121236122124435112126011...</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>10080</td>
#       <td>2481212170121224121212241212132242224124126</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>10120</td>
#       <td>121213011881112553031515515220106146</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>10123C</td>
#       <td>131-18</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>10123G</td>
#       <td>-38</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>4065</th>
#       <td>gift_0001_20</td>
#       <td>11121101111</td>
#     </tr>
#     <tr>
#       <th>4066</th>
#       <td>gift_0001_30</td>
#       <td>111111301</td>
#     </tr>
#     <tr>
#       <th>4067</th>
#       <td>gift_0001_40</td>
#       <td>111</td>
#     </tr>
#     <tr>
#       <th>4068</th>
#       <td>gift_0001_50</td>
#       <td>1111</td>
#     </tr>
#     <tr>
#       <th>4069</th>
#       <td>m</td>
#       <td>1</td>
#     </tr>
#   </tbody>
# </table>
# <p>4070 rows × 2 columns</p>
# </div>

# %% [markdown]
# ### 5. Usar a função max em alguma coluna do DataFrame

# %%
df.groupby('stock_code').agg(soma=('quantity','max')).reset_index()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>stock_code</th>
#       <th>soma</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>10002</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>10080</td>
#       <td>48</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>10120</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>10123C</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>10123G</td>
#       <td>-38</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>4065</th>
#       <td>gift_0001_20</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>4066</th>
#       <td>gift_0001_30</td>
#       <td>30</td>
#     </tr>
#     <tr>
#       <th>4067</th>
#       <td>gift_0001_40</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>4068</th>
#       <td>gift_0001_50</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>4069</th>
#       <td>m</td>
#       <td>1</td>
#     </tr>
#   </tbody>
# </table>
# <p>4070 rows × 2 columns</p>
# </div>

# %%
df['unit_price'].max()
# Out:
# Out[20]: '99,96'
